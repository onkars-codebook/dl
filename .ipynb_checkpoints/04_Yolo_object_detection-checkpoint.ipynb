# %% [markdown]
# # Experiment 4: YOLO Object Detection
#
# This notebook implements YOLO object detection based on the practical.
# It includes:
# - image inference (default, notebook-friendly)
# - optional webcam inference loop (for local GUI environments)

# %%
# !pip install numpy pandas matplotlib "ultralytics>=8.0" "opencv-python-headless>=4.8"
# Out:
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (2.4.4)
# Collecting pandas
#   Using cached pandas-3.0.2-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.10.9)
# Requirement already satisfied: ultralytics>=8.0 in /opt/conda/lib/python3.11/site-packages (8.4.47)
# Requirement already satisfied: opencv-python-headless>=4.8 in /opt/conda/lib/python3.11/site-packages (4.13.0.92)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.0) (4.13.0.92)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.0) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.0) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.0) (1.17.1)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.0) (2.11.0)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.0) (0.26.0)
# Requirement already satisfied: psutil>=5.8.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.0) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.0) (1.40.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in /opt/conda/lib/python3.11/site-packages (from ultralytics>=8.0) (2.0.19)
# Requirement already satisfied: polars-runtime-32==1.40.1 in /opt/conda/lib/python3.11/site-packages (from polars>=0.20.0->ultralytics>=8.0) (1.40.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics>=8.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics>=8.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics>=8.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.23.0->ultralytics>=8.0) (2023.7.22)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (4.15.0)
# Requirement already satisfied: setuptools<82 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (68.2.2)
# Requirement already satisfied: sympy>=1.13.3 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (3.6.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (3.1.2)
# Requirement already satisfied: fsspec>=0.8.5 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (2026.4.0)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /opt/conda/lib/python3.11/site-packages (from torch>=1.8.0->ultralytics>=8.0) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /opt/conda/lib/python3.11/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=1.8.0->ultralytics>=8.0) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /opt/conda/lib/python3.11/site-packages (from cuda-bindings<14,>=13.0.3->torch>=1.8.0->ultralytics>=8.0) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics>=8.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch>=1.8.0->ultralytics>=8.0) (2.1.3)
# Downloading pandas-3.0.2-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 8.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pandas
# Successfully installed pandas-3.0.2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from urllib.request import urlretrieve
from ultralytics import YOLO
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import cv2
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ImportError: libxcb.so.1: cannot open shared object file: No such file or directory

# %%
# Load pretrained YOLO model.
model = YOLO("yolov8n.pt")

# Use local image.jpg if present; otherwise download a sample image.
image_path = Path("image.jpg")
if not image_path.exists():
    sample_url = "https://ultralytics.com/images/bus.jpg"
    urlretrieve(sample_url, image_path)
    print(f"Downloaded sample image to: {image_path.resolve()}")

img = cv2.imread(str(image_path))
if img is None:
    raise FileNotFoundError(f"Could not read image: {image_path}")

results = model(img)
annotated = results[0].plot()

plt.figure(figsize=(12, 7))
plt.imshow(cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB))
plt.axis("off")
plt.title("YOLO Detection Result")
plt.show()

# %%
# Print detected objects and confidence.
for box in results[0].boxes:
    cls_id = int(box.cls[0])
    conf = float(box.conf[0])
    print(f"Object: {model.names[cls_id]} | Confidence: {conf:.2f}")

# %%
# Optional: real-time webcam detection.
# Run this block only if your environment has webcam access and GUI display.
RUN_WEBCAM_DEMO = False

if RUN_WEBCAM_DEMO:
    cap = cv2.VideoCapture(0)
    if not cap.isOpened():
        raise RuntimeError("Could not open webcam (index 0)")

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        webcam_results = model(frame)
        annotated_frame = webcam_results[0].plot()
        cv2.imshow("YOLO Object Detection", annotated_frame)

        if cv2.waitKey(1) & 0xFF == ord("q"):
            break

    cap.release()
    cv2.destroyAllWindows()
