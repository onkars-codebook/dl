# %%
# Install tensorflow

# !pip install tensorflow -q

# %%
# ============================================================
# IMPORT LIBRARIES
# ============================================================

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import GRU
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Bidirectional

# %%
# ============================================================
# LOAD IMDB DATASET
# ============================================================

# num_words = top 10000 most frequent words

vocab_size = 10000

(x_train, y_train), (x_test, y_test) = imdb.load_data(
    num_words=vocab_size
)

print("Training Samples :", len(x_train))
print("Testing Samples :", len(x_test))
# Out:
# Training Samples : 25000
# Testing Samples : 25000

# %%
# ============================================================
# DISPLAY SAMPLE REVIEW
# ============================================================

print("Sample Review (Encoded):")
print(x_train[0])

print("\nSentiment Label:")
print(y_train[0])

# 0 = Negative
# 1 = Positive
# Out:
# Sample Review (Encoded):
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
#
# Sentiment Label:
# 1

# %%
# ============================================================
# PADDING SEQUENCES
# ============================================================

# Reviews have different lengths
# So we make all reviews same length

max_length = 200

x_train = pad_sequences(
    x_train,
    maxlen=max_length
)

x_test = pad_sequences(
    x_test,
    maxlen=max_length
)

print("Shape after Padding:")
print(x_train.shape)
# Out:
# Shape after Padding:
# (25000, 200)

# %%
# ============================================================
# SIMPLE RNN MODEL
# ============================================================

simple_rnn_model = Sequential()

# Word Embedding Layer
simple_rnn_model.add(
    Embedding(vocab_size, 128, input_length=max_length)
)

# Simple RNN Layer
simple_rnn_model.add(
    SimpleRNN(64)
)

# Output Layer
simple_rnn_model.add(
    Dense(1, activation='sigmoid')
)

simple_rnn_model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# ============================================================
# COMPILE SIMPLE RNN MODEL
# ============================================================

simple_rnn_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

print("Simple RNN Model Compiled")
# Out:
# Simple RNN Model Compiled

# %%
# ============================================================
# TRAIN SIMPLE RNN MODEL
# ============================================================

history_rnn = simple_rnn_model.fit(
    x_train,
    y_train,
    epochs=3,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 37s 109ms/step - accuracy: 0.6782 - loss: 0.5866 - val_accuracy: 0.7706 - val_loss: 0.4925
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 42s 112ms/step - accuracy: 0.8333 - loss: 0.3798 - val_accuracy: 0.8182 - val_loss: 0.4488
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 41s 113ms/step - accuracy: 0.7188 - loss: 0.5683 - val_accuracy: 0.6592 - val_loss: 0.6228

# %%
# ============================================================
# EVALUATE SIMPLE RNN
# ============================================================

rnn_loss, rnn_accuracy = simple_rnn_model.evaluate(
    x_test,
    y_test
)

print("Simple RNN Accuracy :", rnn_accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 17ms/step - accuracy: 0.6575 - loss: 0.6175
# Simple RNN Accuracy : 0.657480001449585

# %%
# ============================================================
# LSTM MODEL
# ============================================================

lstm_model = Sequential()

lstm_model.add(
    Embedding(vocab_size, 128, input_length=max_length)
)

# LSTM Layer
lstm_model.add(
    LSTM(64)
)

lstm_model.add(
    Dense(1, activation='sigmoid')
)

lstm_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# ============================================================
# COMPILE LSTM MODEL
# ============================================================

lstm_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

print("LSTM Model Compiled")
# Out:
# LSTM Model Compiled

# %%
# ============================================================
# TRAIN LSTM MODEL
# ============================================================

history_lstm = lstm_model.fit(
    x_train,
    y_train,
    epochs=3,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 94s 293ms/step - accuracy: 0.7685 - loss: 0.4706 - val_accuracy: 0.8386 - val_loss: 0.3736
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 100s 319ms/step - accuracy: 0.8974 - loss: 0.2563 - val_accuracy: 0.8674 - val_loss: 0.3166
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 98s 314ms/step - accuracy: 0.9286 - loss: 0.1893 - val_accuracy: 0.8568 - val_loss: 0.3538

# %%
# ============================================================
# EVALUATE LSTM MODEL
# ============================================================

lstm_loss, lstm_accuracy = lstm_model.evaluate(
    x_test,
    y_test
)

print("LSTM Accuracy :", lstm_accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 39ms/step - accuracy: 0.8492 - loss: 0.3767
# LSTM Accuracy : 0.8492000102996826

# %%
# ============================================================
# GRU MODEL
# ============================================================

gru_model = Sequential()

gru_model.add(
    Embedding(vocab_size, 128, input_length=max_length)
)

# GRU Layer
gru_model.add(
    GRU(64)
)

gru_model.add(
    Dense(1, activation='sigmoid')
)

gru_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# ============================================================
# COMPILE GRU MODEL
# ============================================================

gru_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

print("GRU Model Compiled")
# Out:
# GRU Model Compiled

# %%
# ============================================================
# TRAIN GRU MODEL
# ============================================================

history_gru = gru_model.fit(
    x_train,
    y_train,
    epochs=3,
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 103s 318ms/step - accuracy: 0.7685 - loss: 0.4645 - val_accuracy: 0.8244 - val_loss: 0.4174
# Epoch 2/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 99s 316ms/step - accuracy: 0.8920 - loss: 0.2675 - val_accuracy: 0.8186 - val_loss: 0.3968
# Epoch 3/3
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 99s 317ms/step - accuracy: 0.9257 - loss: 0.1949 - val_accuracy: 0.8624 - val_loss: 0.3421

# %%
# ============================================================
# EVALUATE GRU MODEL
# ============================================================

gru_loss, gru_accuracy = gru_model.evaluate(
    x_test,
    y_test
)

print("GRU Accuracy :", gru_accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.8587 - loss: 0.3457
# GRU Accuracy : 0.8587200045585632

# %%
# ============================================================
# BIDIRECTIONAL LSTM MODEL
# ============================================================

bidirectional_model = Sequential()

bidirectional_model.add(
    Embedding(vocab_size, 128, input_length=max_length)
)

# Bidirectional Layer
bidirectional_model.add(
    Bidirectional(LSTM(64))
)

bidirectional_model.add(
    Dense(1, activation='sigmoid')
)

bidirectional_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_3 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# ============================================================
# COMPILE BIDIRECTIONAL MODEL
# ============================================================

bidirectional_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

print("Bidirectional LSTM Model Compiled")
# Out:
# Bidirectional LSTM Model Compiled

# %%
# ============================================================
# COMPILE BIDIRECTIONAL MODEL
# ============================================================

bidirectional_model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

print("Bidirectional LSTM Model Compiled")
# Out:
# Bidirectional LSTM Model Compiled

# %%
# ============================================================
# EVALUATE BIDIRECTIONAL MODEL
# ============================================================

bidirectional_loss, bidirectional_accuracy = bidirectional_model.evaluate(
    x_test,
    y_test
)

print("Bidirectional LSTM Accuracy :", bidirectional_accuracy)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 52s 65ms/step - accuracy: 0.4967 - loss: 0.6936
# Bidirectional LSTM Accuracy : 0.49667999148368835

# %%
# ============================================================
# COMPARE ALL MODELS
# ============================================================

models = [
    "Simple RNN",
    "LSTM",
    "GRU",
    "Bidirectional LSTM"
]

accuracies = [
    rnn_accuracy,
    lstm_accuracy,
    gru_accuracy,
    bidirectional_accuracy
]

for model, accuracy in zip(models, accuracies):
    print(model, ":", accuracy)
# Out:
# Simple RNN : 0.657480001449585
# LSTM : 0.8492000102996826
# GRU : 0.8587200045585632
# Bidirectional LSTM : 0.49667999148368835

# %%
# ============================================================
# PLOT MODEL ACCURACIES
# ============================================================

plt.figure(figsize=(8,5))

plt.bar(models, accuracies)

plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("RNN Architecture Comparison")

plt.show()

# %%
# ============================================================
# TEST CUSTOM REVIEW
# ============================================================

word_index = imdb.get_word_index()

# Example review
review = "This movie was fantastic and amazing"

# Convert words into numbers
encoded_review = []

for word in review.lower().split():

    if word in word_index:
        encoded_review.append(word_index[word] + 3)

# Padding
encoded_review = pad_sequences(
    [encoded_review],
    maxlen=max_length
)

# Prediction
prediction = lstm_model.predict(encoded_review)

print("Prediction Value :", prediction)

if prediction > 0.5:
    print("Positive Review")
else:
    print("Negative Review")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# Prediction Value : [[0.82422835]]
# Positive Review

# %%
# ============================================================
# CONCLUSION
# ============================================================

print("""
ASSIGNMENT COMPLETED SUCCESSFULLY

Topics Covered:
1. Simple RNN
2. LSTM
3. GRU
4. Bidirectional LSTM
5. Sentiment Analysis using IMDB Dataset

Observations:
- Simple RNN struggles with long-term dependencies
- LSTM handles long text better using memory cells
- GRU is faster and efficient
- Bidirectional LSTM gives better context understanding

Result:
Different RNN architectures were implemented
and compared successfully.
""")
# Out:
# ASSIGNMENT COMPLETED SUCCESSFULLY
#
# Topics Covered:
# 1. Simple RNN
# 2. LSTM
# 3. GRU
# 4. Bidirectional LSTM
# 5. Sentiment Analysis using IMDB Dataset
#
# Observations:
# - Simple RNN struggles with long-term dependencies
# - LSTM handles long text better using memory cells
# - GRU is faster and efficient
# - Bidirectional LSTM gives better context understanding
#
# Result:
# Different RNN architectures were implemented
# and compared successfully.
